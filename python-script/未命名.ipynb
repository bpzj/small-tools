# %%
import QUANTAXIS as qa
# Out:
# PLEASE install TALIB to call these methods
# PLEASE install TALIB to call these methods

# %%
qa.QA_fetch_get_stock_list('tdx')
# Out:
#               code  volunit  decimal_point  name    pre_close sse       sec
# code   sse
# 000001 sz   000001      100              2  平安银行  1304.017500  sz  stock_cn
# 000002 sz   000002      100              2  万 科Ａ    29.480000  sz  stock_cn
# 000004 sz   000004      100              2  国农科技    19.020000  sz  stock_cn
# 000005 sz   000005      100              2  世纪星源  7106.005625  sz  stock_cn
# 000006 sz   000006      100              2  深振业Ａ     6.350000  sz  stock_cn
# 000007 sz   000007      100              2   全新好     7.530000  sz  stock_cn
# 000008 sz   000008      100              2  神州高铁     4.750000  sz  stock_cn
# 000009 sz   000009      100              2  中国宝安     6.220000  sz  stock_cn
# 000010 sz   000010      100              2  美丽生态     4.120000  sz  stock_cn
# 000011 sz   000011      100              2  深物业A   792.007500  sz  stock_cn
# 000012 sz   000012      100              2  南 玻Ａ     5.440000  sz  stock_cn
# ...
